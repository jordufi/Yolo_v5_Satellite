# %% [markdown]
# Basado en https://github.com/ultralytics/yolov5
#
# Usado para imagenes del dataset Xview para detectar solo barcos y aviones

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14998, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 14998 (delta 0), reused 1 (delta 0), pack-reused 14995
# Receiving objects: 100% (14998/14998), 14.08 MiB | 7.13 MiB/s, done.
# Resolving deltas: 100% (10286/10286), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 KB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 106.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 52.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 83.1 MB/s eta 0:00:00
# ...

# %%
#hacer la carpeta de datasets
#crear la carpeta de practica 2
#hacer la carpeta de images
#hacer la carpeta de labels
#/content/datasets/practica2/images/train'
#subir el yaml en data

# %%
# !pwd
# Out:
# /content

# %%
import os
os.mkdir('/content/datasets/')    
os.mkdir('/content/datasets/practica2')
os.mkdir('/content/datasets/practica2/images')
os.mkdir('/content/datasets/practica2/labels')
os.mkdir('/content/datasets/practica2/images/train')
os.mkdir('/content/datasets/practica2/labels/train')
os.mkdir('/content/datasets/practica2/images/test')
os.mkdir('/content/datasets/practica2/labels/test')

# %%
cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 1500 --batch 8 --epochs 120 --data sat2.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=sat2.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=120, batch_size=8, imgsz=1500, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --img 1500 --source /content/datasets/practica2/images/test/ --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.25 --name yolo_road_det
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/datasets/practica2/images/test/, data=data/coco128.yaml, imgsz=[1500, 1500], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolo_road_det, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ --img-size [1500, 1500] must be multiple of max stride 32, updating to [1504, 1504]
# image 1/9 /content/datasets/practica2/images/test/1149.jpg: 1472x1504 10 MOTORBOATs, 2 FISHING_VESSELs, 45.0ms
# ...
